# %%
import os
import sys
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
# Previous cell doesn't add this, so done manually
sys.path.append('C:\\Users\\bde2002.53381\\Desktop\\master-thesis')

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math
import sklearn
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn import preprocessing
import random
from datetime import date
import datetime as DT
from datetime import datetime
import plotly.graph_objects as go
from sklearn.pipeline import Pipeline
from collections import Counter
from matplotlib import pyplot

from quality_evaluation.predictive_metrics import *

# %%
## Assuming that data is prepared:
# - target variable is added and last column
# - variables are added (age) and removed (dates, vital status)
# - categorical variables are encoded appropriatley (ordinal vs nominal)
# - missing values are handled appropriately
# - dummy columns to be dropped are specified outside of function or during preparation

# %%
# Load the original and validation dataframes
df_ori = pd.read_csv("C:\\Users\\bde2002.53381\\Desktop\\master-thesis\\experiments\\data\\data_prepared_for_predictive_metrics\\df_ori_2_binned_p.csv") # This is the original data WITHOUT the holdout validation set
df_ori_val = pd.read_csv("C:\\Users\\bde2002.53381\\Desktop\\master-thesis\\experiments\\data\\data_prepared_for_predictive_metrics\\df_val_2_binned_p.csv")

# %%
epsilon_names = ['10','1','0_1','0_01','0_001']
ms_privacy_levels = []
pb_privacy_levels = []

g = globals()

# The following cells lead to a list (e.g. syn_10) with all the versions of that privacy level, 
# and then to a list privacy_levels that contains all these sublists of the different privay levels with their versions

# %%
# Load ms dataframes for dataset 2
for epsilon in epsilon_names:
    syn_name = 'ms_syn_{}'.format(epsilon)
    g[syn_name] = []
    for versie in range(1,6):
        df = pd.read_csv("C:\\Users\\bde2002.53381\\Desktop\\master-thesis\\experiments\\data\\data_prepared_for_predictive_metrics\\ms\\ms_df_syn_2_e{}_v{}_p.csv".format(epsilon, versie))
        g[syn_name].append(df)
    ms_privacy_levels.append(g[syn_name])

# %%
# Load pb dataframes for dataset 2
for epsilon in epsilon_names:
    syn_name = 'pb_syn_{}'.format(epsilon)
    g[syn_name] = []
    for versie in range(1,6):
        df = pd.read_csv("C:\\Users\\bde2002.53381\\Desktop\\master-thesis\\experiments\\data\\data_prepared_for_predictive_metrics\\pb\\pb_df_syn_2_e{}_v{}_p.csv".format(epsilon, versie))
        g[syn_name].append(df)
    pb_privacy_levels.append(g[syn_name])

# %%
# Dropdummies and num_vars should be specified or can be left None if already taken care of during preperation
dropdummies = ['stage_2A', 'subloc_7', "diagnosis_age_71-90", "lymph_pos_0"]
num_vars = ['tum_differentiatiegraad_code', 'pat_geslacht_code']
models = [LogisticRegression(), DecisionTreeClassifier()]

# %%
# Do for one DP algorithm at a time
privacy_levels = pb_privacy_levels

pb_TB_TOH_ORI, pb_TB_TOH, pb_TB_TOH_ERRORS = TB_TOHmodels(models, df_ori, privacy_levels, df_ori_val, dropdummies=None, num_vars=num_vars)
# Out:
# Applied model is LogisticRegression
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# ori: LogisticRegression(C=1, max_iter=4000)
# Prediction accuracy of original model: 0.6175825007568877
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# syn: LogisticRegression(C=1, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.7081819557977597
# syn: LogisticRegression(C=10, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.707689978807145
# syn: LogisticRegression(C=10, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.706895246745383
# syn: LogisticRegression(C=1, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.7061383590675144
# syn: LogisticRegression(C=10, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.7123826824099304
# TB-TOH Accuracy Difference: -0.09067514380865893 with standard deviation: 0.0021767594843246007
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# syn: LogisticRegression(C=1, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.7018619436875567
# syn: LogisticRegression(C=1, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.7030351195882532
# syn: LogisticRegression(C=0.01, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.7046624280956706
# syn: LogisticRegression(C=0.01, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.6961474417196488
# syn: LogisticRegression(C=0.1, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.7020890099909174
# TB-TOH Accuracy Difference: -0.08397668785952161 with standard deviation: 0.0028798556663791903
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# syn: LogisticRegression(C=0.1, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.6545943082046625
# syn: LogisticRegression(C=0.01, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.6727217680896155
# syn: LogisticRegression(C=0.1, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.682523463518014
# syn: LogisticRegression(C=1, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.6901301846805934
# syn: LogisticRegression(C=0.001, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.6887299424765365
# TB-TOH Accuracy Difference: -0.06015743263699669 with standard deviation: 0.013100249886578028
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# syn: LogisticRegression(C=0.01, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5373145625189222
# syn: LogisticRegression(C=0.01, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.6391537995761429
# syn: LogisticRegression(C=1, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.6313578564940963
# syn: LogisticRegression(C=0.01, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5977898879806237
# syn: LogisticRegression(C=1, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.59763851044505
# TB-TOH Accuracy Difference: 0.01693157735392059 with standard deviation: 0.035928100364536114
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# syn: LogisticRegression(C=100, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5101801392673327
# syn: LogisticRegression(C=0.01, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.505979412655162
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# Only one class left in synthetic dataset, no Logistic Regression possible. Prediction accuracy is set to 0
# syn: LogisticRegression(C=10, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# stage_2C not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_21-50 not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_51-70 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.35289887980623674
# syn: LogisticRegression(C=0.01, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.4842945806842265
# TB-TOH Accuracy Difference: 0.2469118982742961 with standard deviation: 0.19411044436519537
# TB_TOH Accuracay Differences for LogisticRegression : [-0.09067514380865893, -0.08397668785952161, -0.06015743263699669, 0.01693157735392059, 0.2469118982742961]
# Applied model is DecisionTreeClassifier
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# ori: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# Prediction accuracy of original model: 0.5609673024523161
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5609673024523161
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5609673024523161
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5609673024523161
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5609673024523161
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5609673024523161
# TB-TOH Accuracy Difference: 0.0 with standard deviation: 0.0
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5544580684226461
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.6477444747199516
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5613079019073569
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5609673024523161
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.6433545261883137
# TB-TOH Accuracy Difference: -0.03259915228580079 with standard deviation: 0.042536795244987234
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.6516046018770815
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.6246215561610657
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5762185891613685
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5605510142294884
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.640478353012413
# TB-TOH Accuracy Difference: -0.0497275204359674 with standard deviation: 0.035937820807670495
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.4942476536481986
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.6331743869209809
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.620420829548895
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5402664244626098
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.4908416590977899
# TB-TOH Accuracy Difference: 0.005177111716621274 with standard deviation: 0.06068313809458497
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=2, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5614214350590372
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=3, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.4947017862549198
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# subloc_4 not present in synthetic dataset, thus dropped from validation set
# stage_1 not present in synthetic dataset, thus dropped from validation set
# stage_3 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=3, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# stage_2C not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_21-50 not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_51-70 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.3476006660611565
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5005298213745081
# TB-TOH Accuracy Difference: 0.06467605207387223 with standard deviation: 0.08113933694355627
# TB_TOH Accuracay Differences for DecisionTreeClassifier : [0.0, -0.03259915228580079, -0.0497275204359674, 0.005177111716621274, 0.06467605207387223]

# %%
# Do for one DP algorithm at a time
privacy_levels = ms_privacy_levels

ms_TB_TOH_ORI, ms_TB_TOH, ms_TB_TOH_ERRORS = TB_TOHmodels(models, df_ori, privacy_levels, df_ori_val, dropdummies=None, num_vars=num_vars)
# Out:
# Applied model is LogisticRegression
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# ori: LogisticRegression(C=1, max_iter=4000)
# Prediction accuracy of original model: 0.6175825007568877
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: LogisticRegression(C=1, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5846957311534968
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5772025431425977
# TB-TOH Accuracy Difference: 0.0388813200121102 with standard deviation: 0.0029972752043596618
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: LogisticRegression(C=1, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5846957311534968
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# diagnosis_age_0-20 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5772025431425977
# TB-TOH Accuracy Difference: 0.03888132001211009 with standard deviation: 0.0029972752043596618
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# diagnosis_age_0-20 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# diagnosis_age_0-20 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# diagnosis_age_0-20 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5772025431425977
# TB-TOH Accuracy Difference: 0.04037995761429003 with standard deviation: 0.0
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# subloc_8 not present in synthetic dataset, thus dropped from validation set
# stage_2C not present in synthetic dataset, thus dropped from validation set
# stage_3A not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_0-20 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# diagnosis_age_0-20 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# stage_2C not present in synthetic dataset, thus dropped from validation set
# stage_4C not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5772025431425977
# TB-TOH Accuracy Difference: 0.04037995761429003 with standard deviation: 0.0
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# Only one class left in synthetic dataset, no Logistic Regression possible. Prediction accuracy is set to 0
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# subloc_0 not present in synthetic dataset, thus dropped from validation set
# subloc_3 not present in synthetic dataset, thus dropped from validation set
# stage_1 not present in synthetic dataset, thus dropped from validation set
# stage_2 not present in synthetic dataset, thus dropped from validation set
# stage_2C not present in synthetic dataset, thus dropped from validation set
# stage_3 not present in synthetic dataset, thus dropped from validation set
# stage_3A not present in synthetic dataset, thus dropped from validation set
# stage_4A not present in synthetic dataset, thus dropped from validation set
# stage_4C not present in synthetic dataset, thus dropped from validation set
# stage_M not present in synthetic dataset, thus dropped from validation set
# stage_X not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# subloc_3 not present in synthetic dataset, thus dropped from validation set
# subloc_4 not present in synthetic dataset, thus dropped from validation set
# subloc_8 not present in synthetic dataset, thus dropped from validation set
# subloc_9 not present in synthetic dataset, thus dropped from validation set
# stage_1 not present in synthetic dataset, thus dropped from validation set
# stage_2 not present in synthetic dataset, thus dropped from validation set
# stage_2A not present in synthetic dataset, thus dropped from validation set
# stage_2C not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_0-20 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# subloc_3 not present in synthetic dataset, thus dropped from validation set
# subloc_9 not present in synthetic dataset, thus dropped from validation set
# stage_2 not present in synthetic dataset, thus dropped from validation set
# stage_3 not present in synthetic dataset, thus dropped from validation set
# stage_4C not present in synthetic dataset, thus dropped from validation set
# stage_M not present in synthetic dataset, thus dropped from validation set
# stage_X not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# subloc_0 not present in synthetic dataset, thus dropped from validation set
# subloc_3 not present in synthetic dataset, thus dropped from validation set
# subloc_6 not present in synthetic dataset, thus dropped from validation set
# subloc_8 not present in synthetic dataset, thus dropped from validation set
# stage_2B not present in synthetic dataset, thus dropped from validation set
# stage_3 not present in synthetic dataset, thus dropped from validation set
# stage_4A not present in synthetic dataset, thus dropped from validation set
# stage_4B not present in synthetic dataset, thus dropped from validation set
# stage_M not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_21-50 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.4227974568574024
# TB-TOH Accuracy Difference: 0.18670148349984866 with standard deviation: 0.22358611843924028
# TB_TOH Accuracay Differences for LogisticRegression : [0.0388813200121102, 0.03888132001211009, 0.04037995761429003, 0.04037995761429003, 0.18670148349984866]
# Applied model is DecisionTreeClassifier
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# ori: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# Prediction accuracy of original model: 0.5609673024523161
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5772025431425977
# TB-TOH Accuracy Difference: -0.016235240690281594 with standard deviation: 0.0
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# diagnosis_age_0-20 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5772025431425977
# TB-TOH Accuracy Difference: -0.016235240690281594 with standard deviation: 0.0
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# diagnosis_age_0-20 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# diagnosis_age_0-20 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# diagnosis_age_0-20 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5772025431425977
# TB-TOH Accuracy Difference: -0.016235240690281594 with standard deviation: 0.0
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# subloc_8 not present in synthetic dataset, thus dropped from validation set
# stage_2C not present in synthetic dataset, thus dropped from validation set
# stage_3A not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_0-20 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# diagnosis_age_0-20 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# stage_2C not present in synthetic dataset, thus dropped from validation set
# stage_4C not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5772025431425977
# TB-TOH Accuracy Difference: -0.016235240690281594 with standard deviation: 0.0
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# subloc_3 not present in synthetic dataset, thus dropped from validation set
# subloc_6 not present in synthetic dataset, thus dropped from validation set
# subloc_9 not present in synthetic dataset, thus dropped from validation set
# stage_2 not present in synthetic dataset, thus dropped from validation set
# stage_2B not present in synthetic dataset, thus dropped from validation set
# stage_4A not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_21-50 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# subloc_0 not present in synthetic dataset, thus dropped from validation set
# subloc_3 not present in synthetic dataset, thus dropped from validation set
# stage_1 not present in synthetic dataset, thus dropped from validation set
# stage_2 not present in synthetic dataset, thus dropped from validation set
# stage_2C not present in synthetic dataset, thus dropped from validation set
# stage_3 not present in synthetic dataset, thus dropped from validation set
# stage_3A not present in synthetic dataset, thus dropped from validation set
# stage_4A not present in synthetic dataset, thus dropped from validation set
# stage_4C not present in synthetic dataset, thus dropped from validation set
# stage_M not present in synthetic dataset, thus dropped from validation set
# stage_X not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# subloc_3 not present in synthetic dataset, thus dropped from validation set
# subloc_4 not present in synthetic dataset, thus dropped from validation set
# subloc_8 not present in synthetic dataset, thus dropped from validation set
# subloc_9 not present in synthetic dataset, thus dropped from validation set
# stage_1 not present in synthetic dataset, thus dropped from validation set
# stage_2 not present in synthetic dataset, thus dropped from validation set
# stage_2A not present in synthetic dataset, thus dropped from validation set
# stage_2C not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_0-20 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# subloc_3 not present in synthetic dataset, thus dropped from validation set
# subloc_9 not present in synthetic dataset, thus dropped from validation set
# stage_2 not present in synthetic dataset, thus dropped from validation set
# stage_3 not present in synthetic dataset, thus dropped from validation set
# stage_4C not present in synthetic dataset, thus dropped from validation set
# stage_M not present in synthetic dataset, thus dropped from validation set
# stage_X not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5772025431425977
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# diagnosis_age_0-20 present in original data, thus added to validation data with value 0
# subloc_0 not present in synthetic dataset, thus dropped from validation set
# subloc_3 not present in synthetic dataset, thus dropped from validation set
# subloc_6 not present in synthetic dataset, thus dropped from validation set
# subloc_8 not present in synthetic dataset, thus dropped from validation set
# stage_2B not present in synthetic dataset, thus dropped from validation set
# stage_3 not present in synthetic dataset, thus dropped from validation set
# stage_4A not present in synthetic dataset, thus dropped from validation set
# stage_4B not present in synthetic dataset, thus dropped from validation set
# stage_M not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_21-50 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.4227974568574024
# TB-TOH Accuracy Difference: 0.014645776566757474 with standard deviation: 0.06176203451407811
# TB_TOH Accuracay Differences for DecisionTreeClassifier : [-0.016235240690281594, -0.016235240690281594, -0.016235240690281594, -0.016235240690281594, 0.014645776566757474]

# %%
labels = ['very low', 'low', 'medium', 'high', 'very high']

# %%
QMbar_one_DP_alg(QM=pb_TB_TOH, QMerror = pb_TB_TOH_ERRORS, QMname='TB-TOH Accuracy Difference PB', labels=labels)

# %%
QMbar_one_DP_alg(QM=ms_TB_TOH, QMerror = ms_TB_TOH_ERRORS, QMname='TB-TOH Accuracy Difference MS', labels=labels)

# %% [markdown]
# # Combined visualization

# %%
QMori = ms_TB_TOH_ORI+pb_TB_TOH_ORI
QMTB_TOH = ms_TB_TOH+pb_TB_TOH
QMerror = ms_TB_TOH_ERRORS+pb_TB_TOH_ERRORS

# %%
fig = QMbar_two_DP_algs(QM=QMTB_TOH, QMerror = QMerror, QMname='TB-TOH Accuracy Difference', QMori = QMori, labels=labels)
fig.savefig('C:\\Users\\bde2002.53381\\Desktop\\master-thesis\\experiments\\evaluation_results\\Final Result TB-TOH Accuracy Difference-subset_2.png', bbox_inches='tight', dpi=100)

# %%
# Due to the Xval split for this subset the accuracy is very low when using decision tree or logistic regression, even without strict overfitting parameter values the acc is only 67% (and same for LR)

# %%
df_ori_val.head()
# Set X and y for original data
X_val = df_ori_val.iloc[:,:-1]
y_val = df_ori_val.iloc[:,-1] 

X_val['diagnosis_age_0-20'] = 0

# %%
df_ori.head()
# Set X and y for original data
X_ori = df_ori.iloc[:,:-1]
y_ori = df_ori.iloc[:,-1]

# %%
clf=DecisionTreeClassifier()#min_samples_leaf=0.005)

# %%
clf.fit(X_ori, y_ori)
# Out:
# DecisionTreeClassifier()

# %%
clf.score(X_val, y_val)
# Out:
# 0.6654556463820769

# %%
clf2=LogisticRegression(max_iter=4000)

# %%
clf2.fit(X_ori, y_ori)
# Out:
# LogisticRegression(max_iter=4000)

# %%
clf2.score(X_val, y_val)
# Out:
# 0.6175825007568877
