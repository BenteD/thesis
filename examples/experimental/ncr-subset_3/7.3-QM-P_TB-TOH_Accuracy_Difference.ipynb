# %%
import os
import sys
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
# Previous cell doesn't add this, so done manually
sys.path.append('C:\\Users\\bde2002.53381\\Desktop\\master-thesis')

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math
import sklearn
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn import preprocessing
import random
from datetime import date
import datetime as DT
from datetime import datetime
import plotly.graph_objects as go
from sklearn.pipeline import Pipeline
from collections import Counter
from matplotlib import pyplot

from quality_evaluation.predictive_metrics import *

# %%
## Assuming that data is prepared:
# - target variable is added and last column
# - variables are added (age) and removed (dates, vital status)
# - categorical variables are encoded appropriatley (ordinal vs nominal)
# - missing values are handled appropriately
# - dummy columns to be dropped are specified outside of function or during preparation

# %%
# Load the original and validation dataframes
df_ori = pd.read_csv("C:\\Users\\bde2002.53381\\Desktop\\master-thesis\\experiments\\data\\data_prepared_for_predictive_metrics\\df_ori_3_binned_p.csv") # This is the original data WITHOUT the holdout validation set
df_ori_val = pd.read_csv("C:\\Users\\bde2002.53381\\Desktop\\master-thesis\\experiments\\data\\data_prepared_for_predictive_metrics\\df_val_3_binned_p.csv")

# %%
epsilon_names = ['10','1','0_1','0_01','0_001']
ms_privacy_levels = []
pb_privacy_levels = []

g = globals()

# The following cells lead to a list (e.g. syn_10) with all the versions of that privacy level, 
# and then to a list privacy_levels that contains all these sublists of the different privay levels with their versions

# %%
# Load ms dataframes for dataset 3
for epsilon in epsilon_names:
    syn_name = 'ms_syn_{}'.format(epsilon)
    g[syn_name] = []
    for versie in range(1,6):
        df = pd.read_csv("C:\\Users\\bde2002.53381\\Desktop\\master-thesis\\experiments\\data\\data_prepared_for_predictive_metrics\\ms\\ms_df_syn_3_e{}_v{}_p.csv".format(epsilon, versie))
        g[syn_name].append(df)
    ms_privacy_levels.append(g[syn_name])

# %%
# Load pb dataframes for dataset 3
for epsilon in epsilon_names:
    syn_name = 'pb_syn_{}'.format(epsilon)
    g[syn_name] = []
    for versie in range(1,6):
        df = pd.read_csv("C:\\Users\\bde2002.53381\\Desktop\\master-thesis\\experiments\\data\\data_prepared_for_predictive_metrics\\pb\\pb_df_syn_3_e{}_v{}_p.csv".format(epsilon, versie))
        g[syn_name].append(df)
    pb_privacy_levels.append(g[syn_name])

# %%
# Dropdummies and num_vars should be specified or can be left None if already taken care of during preperation
dropdummies = ['stage_2A', 'subloc_7', "diagnosis_age_71-90", "lymph_pos_0"]
num_vars = ['tum_differentiatiegraad_code', 'pat_geslacht_code']
models = [LogisticRegression(), DecisionTreeClassifier()]

# %%
# Do for one DP algorithm at a time
privacy_levels = pb_privacy_levels

pb_TB_TOH_ORI, pb_TB_TOH, pb_TB_TOH_ERRORS = TB_TOHmodels(models, df_ori, privacy_levels, df_ori_val, dropdummies=None, num_vars=num_vars)
# Out:
# Applied model is LogisticRegression
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# ori: LogisticRegression(C=1, max_iter=4000)
# Prediction accuracy of original model: 0.7525734181047532
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# syn: LogisticRegression(C=1, max_iter=4000)
# Prediction accuracy of synthetic model: 0.7499243112322131
# syn: LogisticRegression(C=10, max_iter=4000)
# Prediction accuracy of synthetic model: 0.7493188010899182
# syn: LogisticRegression(C=1, max_iter=4000)
# Prediction accuracy of synthetic model: 0.749735089312746
# syn: LogisticRegression(C=10, max_iter=4000)
# Prediction accuracy of synthetic model: 0.7492431123221314
# syn: LogisticRegression(C=1, max_iter=4000)
# Prediction accuracy of synthetic model: 0.7484862246442628
# TB-TOH Accuracy Difference: 0.0032319103844988817 with standard deviation: 0.0004972469786756438
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# syn: LogisticRegression(C=10, max_iter=4000)
# Prediction accuracy of synthetic model: 0.7431501665152891
# syn: LogisticRegression(C=100, max_iter=4000)
# Prediction accuracy of synthetic model: 0.7426581895246746
# syn: LogisticRegression(C=0.1, max_iter=4000)
# Prediction accuracy of synthetic model: 0.7386088404480775
# syn: LogisticRegression(C=0.01, max_iter=4000)
# Prediction accuracy of synthetic model: 0.7427338782924614
# syn: LogisticRegression(C=0.01, max_iter=4000)
# Prediction accuracy of synthetic model: 0.7405389040266425
# TB-TOH Accuracy Difference: 0.01103542234332422 with standard deviation: 0.0017240764936103357
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# syn: LogisticRegression(C=0.001, max_iter=4000)
# Prediction accuracy of synthetic model: 0.6958825310323948
# syn: LogisticRegression(C=0.01, max_iter=4000)
# Prediction accuracy of synthetic model: 0.7045867393278837
# syn: LogisticRegression(C=0.01, max_iter=4000)
# Prediction accuracy of synthetic model: 0.6877459884953073
# syn: LogisticRegression(C=0.01, max_iter=4000)
# Prediction accuracy of synthetic model: 0.7045867393278837
# syn: LogisticRegression(C=0.001, max_iter=4000)
# Prediction accuracy of synthetic model: 0.6731759006963367
# TB-TOH Accuracy Difference: 0.059377838328791954 with standard deviation: 0.011808660673476022
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# syn: LogisticRegression(C=10, max_iter=4000)
# Prediction accuracy of synthetic model: 0.5968059339993945
# syn: LogisticRegression(C=0.001, max_iter=4000)
# Prediction accuracy of synthetic model: 0.6281789282470481
# syn: LogisticRegression(C=10, max_iter=4000)
# Prediction accuracy of synthetic model: 0.5103693611867999
# syn: LogisticRegression(C=100, max_iter=4000)
# Prediction accuracy of synthetic model: 0.6596654556463821
# syn: LogisticRegression(C=1, max_iter=4000)
# Prediction accuracy of synthetic model: 0.6097487132909476
# TB-TOH Accuracy Difference: 0.15161973963063868 with standard deviation: 0.04997671850770195
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# syn: LogisticRegression(C=0.001, max_iter=4000)
# Prediction accuracy of synthetic model: 0.5082879200726612
# syn: LogisticRegression(C=0.01, max_iter=4000)
# Prediction accuracy of synthetic model: 0.5220632758098698
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# stage_4C not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.4228353012412958
# syn: LogisticRegression(C=0.001, max_iter=4000)
# subloc_0 not present in synthetic dataset, thus dropped from validation set
# subloc_4 not present in synthetic dataset, thus dropped from validation set
# subloc_6 not present in synthetic dataset, thus dropped from validation set
# subloc_8 not present in synthetic dataset, thus dropped from validation set
# subloc_9 not present in synthetic dataset, thus dropped from validation set
# stage_2C not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_0-20 not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_21-50 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5175597941265516
# syn: LogisticRegression(C=10, max_iter=4000)
# stage_2C not present in synthetic dataset, thus dropped from validation set
# stage_4A not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5739479261277627
# TB-TOH Accuracy Difference: 0.24363457462912497 with standard deviation: 0.04875858084085259
# TB_TOH Accuracay Differences for LogisticRegression : [0.0032319103844988817, 0.01103542234332422, 0.059377838328791954, 0.15161973963063868, 0.24363457462912497]
# Applied model is DecisionTreeClassifier
# ori: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# Prediction accuracy of original model: 0.7195731153496822
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.7195731153496822
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.7195731153496822
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.7195731153496822
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.7195731153496822
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.7195731153496822
# TB-TOH Accuracy Difference: 0.0 with standard deviation: 0.0
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.704700272479564
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.7134801695428399
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.6900923402967
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.7019754768392371
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.6992885255828035
# TB-TOH Accuracy Difference: 0.017665758401453235 with standard deviation: 0.007591941846868324
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.6892219194671511
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.6449061459279443
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=4, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.6397214653345443
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.6975855283075991
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.671094459582198
# TB-TOH Accuracy Difference: 0.05106721162579475 with standard deviation: 0.023095328346024523
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.5397744474719952
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.6628065395095368
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.5378065395095368
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.5791326067211626
# TB-TOH Accuracy Difference: 0.14023614895549497 with standard deviation: 0.045303199459430926
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=4, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.5074931880108992
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=4, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.5220632758098698
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# stage_4C not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.4228353012412958
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=4, min_samples_leaf=0.005)
# subloc_0 not present in synthetic dataset, thus dropped from validation set
# subloc_4 not present in synthetic dataset, thus dropped from validation set
# subloc_6 not present in synthetic dataset, thus dropped from validation set
# subloc_8 not present in synthetic dataset, thus dropped from validation set
# subloc_9 not present in synthetic dataset, thus dropped from validation set
# stage_2C not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_0-20 not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_21-50 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5175597941265516
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=3, min_samples_leaf=0.005)
# stage_2C not present in synthetic dataset, thus dropped from validation set
# stage_4A not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5771646987587042
# TB-TOH Accuracy Difference: 0.21014986376021805 with standard deviation: 0.049630787808068066
# TB_TOH Accuracay Differences for DecisionTreeClassifier : [0.0, 0.017665758401453235, 0.05106721162579475, 0.14023614895549497, 0.21014986376021805]

# %%
# Do for one DP algorithm at a time
privacy_levels = ms_privacy_levels

ms_TB_TOH_ORI, ms_TB_TOH, ms_TB_TOH_ERRORS = TB_TOHmodels(models, df_ori, privacy_levels, df_ori_val, dropdummies=None, num_vars=num_vars)
# Out:
# Applied model is LogisticRegression
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# ori: LogisticRegression(C=1, max_iter=4000)
# Prediction accuracy of original model: 0.7525734181047532
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# Prediction accuracy of synthetic model: 0.5771646987587042
# TB-TOH Accuracy Difference: 0.17540871934604896 with standard deviation: 0.0
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# Prediction accuracy of synthetic model: 0.5771646987587042
# TB-TOH Accuracy Difference: 0.17540871934604896 with standard deviation: 0.0
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# diagnosis_age_0-20 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5771646987587042
# TB-TOH Accuracy Difference: 0.17540871934604896 with standard deviation: 0.0
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# subloc_8 not present in synthetic dataset, thus dropped from validation set
# stage_3A not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# stage_2C not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_0-20 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# stage_2C not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_0-20 not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_91-120 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: LogisticRegression(C=1, max_iter=4000)
# diagnosis_age_0-20 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5739100817438693
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# stage_3A not present in synthetic dataset, thus dropped from validation set
# stage_4C not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5771646987587042
# TB-TOH Accuracy Difference: 0.17605964274901598 with standard deviation: 0.0013018468059339927
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 335, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\bde2002.53381\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py", line 1374, in fit
#     " class: %r" % classes_[0])
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   FitFailedWarning)
# Only one class left in synthetic dataset, no Logistic Regression possible. Prediction accuracy is set to 0
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# subloc_2 not present in synthetic dataset, thus dropped from validation set
# subloc_4 not present in synthetic dataset, thus dropped from validation set
# subloc_6 not present in synthetic dataset, thus dropped from validation set
# stage_2 not present in synthetic dataset, thus dropped from validation set
# stage_2B not present in synthetic dataset, thus dropped from validation set
# stage_2C not present in synthetic dataset, thus dropped from validation set
# stage_3A not present in synthetic dataset, thus dropped from validation set
# stage_4 not present in synthetic dataset, thus dropped from validation set
# stage_4B not present in synthetic dataset, thus dropped from validation set
# stage_M not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_0-20 not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_21-50 not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_91-120 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# subloc_4 not present in synthetic dataset, thus dropped from validation set
# subloc_6 not present in synthetic dataset, thus dropped from validation set
# subloc_8 not present in synthetic dataset, thus dropped from validation set
# subloc_9 not present in synthetic dataset, thus dropped from validation set
# stage_2C not present in synthetic dataset, thus dropped from validation set
# stage_3A not present in synthetic dataset, thus dropped from validation set
# stage_3B not present in synthetic dataset, thus dropped from validation set
# stage_4 not present in synthetic dataset, thus dropped from validation set
# stage_4A not present in synthetic dataset, thus dropped from validation set
# stage_M not present in synthetic dataset, thus dropped from validation set
# stage_X not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_0-20 not present in synthetic dataset, thus dropped from validation set
# lymph_pos_1-89 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.4228353012412958
# syn: LogisticRegression(C=0.01, max_iter=4000)
# stage_3 not present in synthetic dataset, thus dropped from validation set
# stage_3A not present in synthetic dataset, thus dropped from validation set
# stage_3B not present in synthetic dataset, thus dropped from validation set
# stage_4 not present in synthetic dataset, thus dropped from validation set
# stage_4B not present in synthetic dataset, thus dropped from validation set
# stage_M not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_21-50 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.4228353012412958
# syn: LogisticRegression(C=0.0001, max_iter=4000)
# subloc_9 not present in synthetic dataset, thus dropped from validation set
# stage_2C not present in synthetic dataset, thus dropped from validation set
# stage_3 not present in synthetic dataset, thus dropped from validation set
# stage_3A not present in synthetic dataset, thus dropped from validation set
# stage_4 not present in synthetic dataset, thus dropped from validation set
# stage_M not present in synthetic dataset, thus dropped from validation set
# stage_X not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_0-20 not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_51-70 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5771646987587042
# TB-TOH Accuracy Difference: 0.3525734181047532 with standard deviation: 0.21157389391798143
# TB_TOH Accuracay Differences for LogisticRegression : [0.17540871934604896, 0.17540871934604896, 0.17540871934604896, 0.17605964274901598, 0.3525734181047532]
# Applied model is DecisionTreeClassifier
# ori: DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=0.005)
# Prediction accuracy of original model: 0.7195731153496822
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.5771646987587042
# TB-TOH Accuracy Difference: 0.14240841659097792 with standard deviation: 0.0
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.5771646987587042
# TB-TOH Accuracy Difference: 0.14240841659097792 with standard deviation: 0.0
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# diagnosis_age_0-20 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5771646987587042
# TB-TOH Accuracy Difference: 0.14240841659097792 with standard deviation: 0.0
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# subloc_8 not present in synthetic dataset, thus dropped from validation set
# stage_3A not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# stage_2C not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_0-20 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# stage_2C not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_0-20 not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_91-120 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# diagnosis_age_0-20 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# stage_3A not present in synthetic dataset, thus dropped from validation set
# stage_4C not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5771646987587042
# TB-TOH Accuracy Difference: 0.14240841659097792 with standard deviation: 0.0
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# subloc_0 not present in synthetic dataset, thus dropped from validation set
# subloc_2 not present in synthetic dataset, thus dropped from validation set
# subloc_9 not present in synthetic dataset, thus dropped from validation set
# stage_3A not present in synthetic dataset, thus dropped from validation set
# stage_4C not present in synthetic dataset, thus dropped from validation set
# stage_M not present in synthetic dataset, thus dropped from validation set
# stage_X not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_0-20 not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_91-120 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# subloc_2 not present in synthetic dataset, thus dropped from validation set
# subloc_4 not present in synthetic dataset, thus dropped from validation set
# subloc_6 not present in synthetic dataset, thus dropped from validation set
# stage_2 not present in synthetic dataset, thus dropped from validation set
# stage_2B not present in synthetic dataset, thus dropped from validation set
# stage_2C not present in synthetic dataset, thus dropped from validation set
# stage_3A not present in synthetic dataset, thus dropped from validation set
# stage_4 not present in synthetic dataset, thus dropped from validation set
# stage_4B not present in synthetic dataset, thus dropped from validation set
# stage_M not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_0-20 not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_21-50 not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_91-120 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5771646987587042
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# subloc_4 not present in synthetic dataset, thus dropped from validation set
# subloc_6 not present in synthetic dataset, thus dropped from validation set
# subloc_8 not present in synthetic dataset, thus dropped from validation set
# subloc_9 not present in synthetic dataset, thus dropped from validation set
# stage_2C not present in synthetic dataset, thus dropped from validation set
# stage_3A not present in synthetic dataset, thus dropped from validation set
# stage_3B not present in synthetic dataset, thus dropped from validation set
# stage_4 not present in synthetic dataset, thus dropped from validation set
# stage_4A not present in synthetic dataset, thus dropped from validation set
# stage_M not present in synthetic dataset, thus dropped from validation set
# stage_X not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_0-20 not present in synthetic dataset, thus dropped from validation set
# lymph_pos_1-89 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.4228353012412958
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# stage_3 not present in synthetic dataset, thus dropped from validation set
# stage_3A not present in synthetic dataset, thus dropped from validation set
# stage_3B not present in synthetic dataset, thus dropped from validation set
# stage_4 not present in synthetic dataset, thus dropped from validation set
# stage_4B not present in synthetic dataset, thus dropped from validation set
# stage_M not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_21-50 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.4228353012412958
# syn: DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=0.005)
# subloc_9 not present in synthetic dataset, thus dropped from validation set
# stage_2C not present in synthetic dataset, thus dropped from validation set
# stage_3 not present in synthetic dataset, thus dropped from validation set
# stage_3A not present in synthetic dataset, thus dropped from validation set
# stage_4 not present in synthetic dataset, thus dropped from validation set
# stage_M not present in synthetic dataset, thus dropped from validation set
# stage_X not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_0-20 not present in synthetic dataset, thus dropped from validation set
# diagnosis_age_51-70 not present in synthetic dataset, thus dropped from validation set
# Prediction accuracy of synthetic model: 0.5771646987587042
# TB-TOH Accuracy Difference: 0.2041401755979414 with standard deviation: 0.07560565524575992
# TB_TOH Accuracay Differences for DecisionTreeClassifier : [0.14240841659097792, 0.14240841659097792, 0.14240841659097792, 0.14240841659097792, 0.2041401755979414]

# %%
labels = ['very low', 'low', 'medium', 'high', 'very high']

# %%
QMbar_one_DP_alg(QM=pb_TB_TOH, QMerror = pb_TB_TOH_ERRORS, QMname='TB-TOH Accuracy Difference PB', labels=labels)

# %%
QMbar_one_DP_alg(QM=ms_TB_TOH, QMerror = ms_TB_TOH_ERRORS, QMname='TB-TOH Accuracy Difference MS', labels=labels)

# %% [markdown]
# # Combined visualization

# %%
QMori = ms_TB_TOH_ORI+pb_TB_TOH_ORI
QMTB_TOH = ms_TB_TOH+pb_TB_TOH
QMerror = ms_TB_TOH_ERRORS+pb_TB_TOH_ERRORS

# %%
fig = QMbar_two_DP_algs(QM=QMTB_TOH, QMerror = QMerror, QMname='TB-TOH Accuracy Difference', QMori = QMori, labels=labels)
fig.savefig('C:\\Users\\bde2002.53381\\Desktop\\master-thesis\\experiments\\evaluation_results\\Final Result TB-TOH Accuracy Difference-subset_3.png', bbox_inches='tight', dpi=100)
