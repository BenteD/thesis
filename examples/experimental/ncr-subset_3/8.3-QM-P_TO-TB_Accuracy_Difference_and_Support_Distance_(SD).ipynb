# %%
import os
import sys
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
# Previous cell doesn't add this, so done manually
sys.path.append('C:\\Users\\bde2002.53381\\Desktop\\master-thesis')

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math
import sklearn
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn import preprocessing
import random
from datetime import date
import datetime as DT
from datetime import datetime
import plotly.graph_objects as go
from sklearn.pipeline import Pipeline
from collections import Counter
from matplotlib import pyplot

from quality_evaluation.predictive_metrics import *

# %%
## Assuming that data is prepared:
# - target variable is added and last column
# - variables are added (age) and removed (dates, vital status)
# - categorical variables are encoded appropriatley (ordinal vs nominal)
# - missing values are handled appropriately
# - dummy columns to be dropped are specified outside of function or during preparation

# %%
# Load the original and validation dataframes
df_ori = pd.read_csv("C:\\Users\\bde2002.53381\\Desktop\\master-thesis\\experiments\\data\\data_prepared_for_predictive_metrics\\df_ori_3_binned_p.csv") # This is the original data WITHOUT the holdout validation set
df_ori_val = pd.read_csv("C:\\Users\\bde2002.53381\\Desktop\\master-thesis\\experiments\\data\\data_prepared_for_predictive_metrics\\df_val_3_binned_p.csv")

# %%
epsilon_names = ['10','1','0_1','0_01','0_001']
ms_privacy_levels = []
pb_privacy_levels = []

g = globals()

# The following cells lead to a list (e.g. syn_10) with all the versions of that privacy level, 
# and then to a list privacy_levels that contains all these sublists of the different privay levels with their versions

# %%
# Load ms dataframes for dataset 3
for epsilon in epsilon_names:
    syn_name = 'ms_syn_{}'.format(epsilon)
    g[syn_name] = []
    for versie in range(1,6):
        df = pd.read_csv("C:\\Users\\bde2002.53381\\Desktop\\master-thesis\\experiments\\data\\data_prepared_for_predictive_metrics\\ms\\ms_df_syn_3_e{}_v{}_p.csv".format(epsilon, versie))
        g[syn_name].append(df)
    ms_privacy_levels.append(g[syn_name])

# %%
# Load pb dataframes for dataset 3
for epsilon in epsilon_names:
    syn_name = 'pb_syn_{}'.format(epsilon)
    g[syn_name] = []
    for versie in range(1,6):
        df = pd.read_csv("C:\\Users\\bde2002.53381\\Desktop\\master-thesis\\experiments\\data\\data_prepared_for_predictive_metrics\\pb\\pb_df_syn_3_e{}_v{}_p.csv".format(epsilon, versie))
        g[syn_name].append(df)
    pb_privacy_levels.append(g[syn_name])

# %%
# Dropdummies and num_vars should be specified or can be left None if already taken care of during preperation
dropdummies = ['stage_2A', 'subloc_7', "diagnosis_age_71-90", "lymph_pos_0"]
num_vars = ['tum_differentiatiegraad_code', 'pat_geslacht_code']
models = [LogisticRegression(), DecisionTreeClassifier()]

# %%
# Do for one DP algorithm at a time
privacy_levels = pb_privacy_levels

pb_TO_TB_ORI, pb_TO_TB, pb_TO_TB_ERRORS, pb_SD, pb_SD_ERRORS = TO_TBmodels(models, df_ori, privacy_levels, df_ori_val, dropdummies=None, num_vars=num_vars)
# Out:
# Applied model is LogisticRegression
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# Accuracy on data that trained the model: 0.7548039169307914
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# Prediction accuracy of synthetic data: 0.7323336014002555
# Prediction accuracy of synthetic data: 0.7346894365864043
# Prediction accuracy of synthetic data: 0.7339420029329675
# Prediction accuracy of synthetic data: 0.7364113723449548
# Prediction accuracy of synthetic data: 0.7330621126827191
# TO-TB accuracy difference with same training data: 0.020716211741331203 with standard deviation: 0.001407938845570033
# Support Distance not applicable
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# Prediction accuracy of synthetic data: 0.6311273002507214
# Prediction accuracy of synthetic data: 0.6281186432660012
# Prediction accuracy of synthetic data: 0.6301054922181749
# Prediction accuracy of synthetic data: 0.6303420218553385
# Prediction accuracy of synthetic data: 0.631363829887885
# TO-TB accuracy difference with same training data: 0.12459245943516717 with standard deviation: 0.0011467237831556353
# Support Distance not applicable
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# Prediction accuracy of synthetic data: 0.5214626992762194
# Prediction accuracy of synthetic data: 0.5228156488007948
# Prediction accuracy of synthetic data: 0.5217654572117887
# Prediction accuracy of synthetic data: 0.5230711008089314
# Prediction accuracy of synthetic data: 0.516845640758787
# TO-TB accuracy difference with same training data: 0.23361180755948718 with standard deviation: 0.0022565560105707117
# Support Distance not applicable
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# Prediction accuracy of synthetic data: 0.52594730119684
# Prediction accuracy of synthetic data: 0.5489379819291357
# Prediction accuracy of synthetic data: 0.5284355929798004
# Prediction accuracy of synthetic data: 0.5824778844789252
# Prediction accuracy of synthetic data: 0.556298784237665
# TO-TB accuracy difference with same training data: 0.20638440796631818 with standard deviation: 0.020623684228398092
# Support Distance not applicable
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# Prediction accuracy of synthetic data: 0.5791286248166896
# Prediction accuracy of synthetic data: 0.5033350678840058
# stage_4C present in original data, thus added to synthetic data with value 0
# Prediction accuracy of synthetic data: 0.4477222195941151
# subloc_0 present in original data, thus added to synthetic data with value 0
# subloc_4 present in original data, thus added to synthetic data with value 0
# subloc_6 present in original data, thus added to synthetic data with value 0
# subloc_8 present in original data, thus added to synthetic data with value 0
# subloc_9 present in original data, thus added to synthetic data with value 0
# stage_2C present in original data, thus added to synthetic data with value 0
# diagnosis_age_0-20 present in original data, thus added to synthetic data with value 0
# diagnosis_age_21-50 present in original data, thus added to synthetic data with value 0
# Prediction accuracy of synthetic data: 0.2991626850844411
# stage_2C present in original data, thus added to synthetic data with value 0
# stage_4A present in original data, thus added to synthetic data with value 0
# Prediction accuracy of synthetic data: 0.7937461563933961
# TO-TB accuracy difference with same training data: 0.23018496617626183 with standard deviation: 0.16284802488483083
# Support Distance not applicable
# TB-TO accuracy difference and support difference for LogisticRegression : [0.020716211741331203, 0.12459245943516717, 0.23361180755948718, 0.20638440796631818, 0.23018496617626183] []
# Applied model is DecisionTreeClassifier
# Accuracy on data that trained the model: 0.7202800510904016
# Prediction accuracy of synthetic data: 0.7039595061261176
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 22
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.005764565157157049
# Prediction accuracy of synthetic data: 0.7029755428355173
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 22
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.0056800902867415
# Prediction accuracy of synthetic data: 0.7028241638677326
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 22
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.00566927750332831
# Prediction accuracy of synthetic data: 0.7029660816500307
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 22
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.005617916782115657
# Prediction accuracy of synthetic data: 0.7023037986659728
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 22
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.005767268353010348
# TO-TB accuracy difference with same training data: 0.01727423246132731 with standard deviation: 0.0005362547853598697
# Prediction accuracy of synthetic data: 0.6149959789961682
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 22
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.01291586978705575
# Prediction accuracy of synthetic data: 0.6168030654240977
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 22
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.013178079784825611
# Prediction accuracy of synthetic data: 0.6130658971569137
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 22
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.013060490765207164
# Prediction accuracy of synthetic data: 0.6149959789961682
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 22
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.013180107181715585
# Prediction accuracy of synthetic data: 0.6130753583424003
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 22
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.013147668831476013
# TO-TB accuracy difference with same training data: 0.10569279530725195 with standard deviation: 0.0014031598366262782
# Prediction accuracy of synthetic data: 0.521964142107006
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 22
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.022085110121441088
# Prediction accuracy of synthetic data: 0.5223804342684139
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 22
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.02187020605110392
# Prediction accuracy of synthetic data: 0.515341312266427
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 22
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.02155528373419476
# Prediction accuracy of synthetic data: 0.5149344812905057
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 22
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.021518114791211917
# Prediction accuracy of synthetic data: 0.5157292208713752
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 22
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.02178978597446832
# TO-TB accuracy difference with same training data: 0.20221013292965606 with standard deviation: 0.003361566526259205
# Prediction accuracy of synthetic data: 0.5274894744311462
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 22
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.022714278956296085
# Prediction accuracy of synthetic data: 0.5335635555135059
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 22
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.023757036756705617
# Prediction accuracy of synthetic data: 0.5189554851222858
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 21
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.02316368526690681
# Prediction accuracy of synthetic data: 0.5634135957235442
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 21
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.01836280943145033
# Prediction accuracy of synthetic data: 0.5664506362647239
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 22
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.022064160353578027
# TO-TB accuracy difference with same training data: 0.17830550167936043 with standard deviation: 0.019334689398622762
# Prediction accuracy of synthetic data: 0.5151615497421826
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 14
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.017188270833192538
# Prediction accuracy of synthetic data: 0.4025639812668527
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 16
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.016661823440762842
# stage_4C present in original data, thus added to synthetic data with value 0
# Prediction accuracy of synthetic data: 0.45057003642556415
# stage_4C present in original data, thus added to synthetic data with value 0
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 10
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.04201847634365729
# subloc_0 present in original data, thus added to synthetic data with value 0
# subloc_4 present in original data, thus added to synthetic data with value 0
# subloc_6 present in original data, thus added to synthetic data with value 0
# subloc_8 present in original data, thus added to synthetic data with value 0
# subloc_9 present in original data, thus added to synthetic data with value 0
# stage_2C present in original data, thus added to synthetic data with value 0
# diagnosis_age_0-20 present in original data, thus added to synthetic data with value 0
# diagnosis_age_21-50 present in original data, thus added to synthetic data with value 0
# Prediction accuracy of synthetic data: 0.2991626850844411
# subloc_0 present in original data, thus added to synthetic data with value 0
# subloc_4 present in original data, thus added to synthetic data with value 0
# subloc_6 present in original data, thus added to synthetic data with value 0
# subloc_8 present in original data, thus added to synthetic data with value 0
# subloc_9 present in original data, thus added to synthetic data with value 0
# stage_2C present in original data, thus added to synthetic data with value 0
# diagnosis_age_0-20 present in original data, thus added to synthetic data with value 0
# diagnosis_age_21-50 present in original data, thus added to synthetic data with value 0
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 3
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.06877943949233982
# stage_2C present in original data, thus added to synthetic data with value 0
# stage_4A present in original data, thus added to synthetic data with value 0
# Prediction accuracy of synthetic data: 0.9431855811533185
# stage_2C present in original data, thus added to synthetic data with value 0
# stage_4A present in original data, thus added to synthetic data with value 0
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 13
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.03125637785271638
# TO-TB accuracy difference with same training data: 0.19815128435592977 with standard deviation: 0.22202146132969833
# TB-TO accuracy difference and support difference for DecisionTreeClassifier : [0.01727423246132731, 0.10569279530725195, 0.20221013292965606, 0.17830550167936043, 0.19815128435592977] [0.005699823616470573, 0.013096443270056024, 0.021763700134484, 0.02201239415298737, 0.03518087759253377]

# %%
# Do for one DP algorithm at a time
privacy_levels = ms_privacy_levels

ms_TO_TB_ORI, ms_TO_TB, ms_TO_TB_ERRORS, ms_SD, ms_SD_ERRORS = TO_TBmodels(models, df_ori, privacy_levels, df_ori_val, dropdummies=None, num_vars=num_vars)
# Out:
# Applied model is LogisticRegression
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# Accuracy on data that trained the model: 0.7548039169307914
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# Prediction accuracy of synthetic data: 0.5106485642651024
# Prediction accuracy of synthetic data: 0.5107999432328871
# Prediction accuracy of synthetic data: 0.5079426652159515
# Prediction accuracy of synthetic data: 0.5100619707649369
# Prediction accuracy of synthetic data: 0.5079615875869247
# TO-TB accuracy difference with same training data: 0.24532097071763082 with standard deviation: 0.0012740026408549307
# Support Distance not applicable
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# Prediction accuracy of synthetic data: 0.5134963810965514
# Prediction accuracy of synthetic data: 0.5134585363546053
# Prediction accuracy of synthetic data: 0.5098159799422868
# Prediction accuracy of synthetic data: 0.5125597237333838
# Prediction accuracy of synthetic data: 0.5116609111121624
# TO-TB accuracy difference with same training data: 0.24260561048299356 with standard deviation: 0.001368800423121796
# Support Distance not applicable
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# Prediction accuracy of synthetic data: 0.5144614220161786
# Prediction accuracy of synthetic data: 0.5116703722976489
# Prediction accuracy of synthetic data: 0.5079237428449784
# Prediction accuracy of synthetic data: 0.5103458063295331
# diagnosis_age_0-20 present in original data, thus added to synthetic data with value 0
# Prediction accuracy of synthetic data: 0.5117839065234874
# TO-TB accuracy difference with same training data: 0.24356686692842622 with standard deviation: 0.002128648150977546
# Support Distance not applicable
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# subloc_8 present in original data, thus added to synthetic data with value 0
# stage_3A present in original data, thus added to synthetic data with value 0
# Prediction accuracy of synthetic data: 0.5302616017787029
# stage_2C present in original data, thus added to synthetic data with value 0
# diagnosis_age_0-20 present in original data, thus added to synthetic data with value 0
# Prediction accuracy of synthetic data: 0.5149439424759923
# stage_2C present in original data, thus added to synthetic data with value 0
# diagnosis_age_0-20 present in original data, thus added to synthetic data with value 0
# diagnosis_age_91-120 present in original data, thus added to synthetic data with value 0
# Prediction accuracy of synthetic data: 0.49772458489048677
# diagnosis_age_0-20 present in original data, thus added to synthetic data with value 0
# Prediction accuracy of synthetic data: 0.5123515776526799
# stage_3A present in original data, thus added to synthetic data with value 0
# stage_4C present in original data, thus added to synthetic data with value 0
# Prediction accuracy of synthetic data: 0.5222574388570888
# TO-TB accuracy difference with same training data: 0.23929608779980127 with standard deviation: 0.010860522142755912
# Support Distance not applicable
# Warning: no dummy columns specified to drop while regression is applied!
# Numerical variables scaled: ['tum_differentiatiegraad_code', 'pat_geslacht_code']
# subloc_0 present in original data, thus added to synthetic data with value 0
# subloc_2 present in original data, thus added to synthetic data with value 0
# subloc_9 present in original data, thus added to synthetic data with value 0
# stage_3A present in original data, thus added to synthetic data with value 0
# stage_4C present in original data, thus added to synthetic data with value 0
# stage_M present in original data, thus added to synthetic data with value 0
# stage_X present in original data, thus added to synthetic data with value 0
# diagnosis_age_0-20 present in original data, thus added to synthetic data with value 0
# diagnosis_age_91-120 present in original data, thus added to synthetic data with value 0
# Prediction accuracy of synthetic data: 1.0
# subloc_2 present in original data, thus added to synthetic data with value 0
# subloc_4 present in original data, thus added to synthetic data with value 0
# subloc_6 present in original data, thus added to synthetic data with value 0
# stage_2 present in original data, thus added to synthetic data with value 0
# stage_2B present in original data, thus added to synthetic data with value 0
# stage_2C present in original data, thus added to synthetic data with value 0
# stage_3A present in original data, thus added to synthetic data with value 0
# stage_4 present in original data, thus added to synthetic data with value 0
# stage_4B present in original data, thus added to synthetic data with value 0
# stage_M present in original data, thus added to synthetic data with value 0
# diagnosis_age_0-20 present in original data, thus added to synthetic data with value 0
# diagnosis_age_21-50 present in original data, thus added to synthetic data with value 0
# diagnosis_age_91-120 present in original data, thus added to synthetic data with value 0
# Prediction accuracy of synthetic data: 0.48409101660438053
# subloc_4 present in original data, thus added to synthetic data with value 0
# subloc_6 present in original data, thus added to synthetic data with value 0
# subloc_8 present in original data, thus added to synthetic data with value 0
# subloc_9 present in original data, thus added to synthetic data with value 0
# stage_2C present in original data, thus added to synthetic data with value 0
# stage_3A present in original data, thus added to synthetic data with value 0
# stage_3B present in original data, thus added to synthetic data with value 0
# stage_4 present in original data, thus added to synthetic data with value 0
# stage_4A present in original data, thus added to synthetic data with value 0
# stage_M present in original data, thus added to synthetic data with value 0
# stage_X present in original data, thus added to synthetic data with value 0
# diagnosis_age_0-20 present in original data, thus added to synthetic data with value 0
# lymph_pos_1-89 present in original data, thus added to synthetic data with value 0
# Prediction accuracy of synthetic data: 0.45219736032924923
# stage_3 present in original data, thus added to synthetic data with value 0
# stage_3A present in original data, thus added to synthetic data with value 0
# stage_3B present in original data, thus added to synthetic data with value 0
# stage_4 present in original data, thus added to synthetic data with value 0
# stage_4B present in original data, thus added to synthetic data with value 0
# stage_M present in original data, thus added to synthetic data with value 0
# diagnosis_age_21-50 present in original data, thus added to synthetic data with value 0
# Prediction accuracy of synthetic data: 0.46974785940678365
# subloc_9 present in original data, thus added to synthetic data with value 0
# stage_2C present in original data, thus added to synthetic data with value 0
# stage_3 present in original data, thus added to synthetic data with value 0
# stage_3A present in original data, thus added to synthetic data with value 0
# stage_4 present in original data, thus added to synthetic data with value 0
# stage_M present in original data, thus added to synthetic data with value 0
# stage_X present in original data, thus added to synthetic data with value 0
# diagnosis_age_0-20 present in original data, thus added to synthetic data with value 0
# diagnosis_age_51-70 present in original data, thus added to synthetic data with value 0
# Prediction accuracy of synthetic data: 0.6928236908084583
# TO-TB accuracy difference with same training data: 0.1350319315010171 with standard deviation: 0.20924039447042295
# Support Distance not applicable
# TB-TO accuracy difference and support difference for LogisticRegression : [0.24532097071763082, 0.24260561048299356, 0.24356686692842622, 0.23929608779980127, 0.1350319315010171] []
# Applied model is DecisionTreeClassifier
# Accuracy on data that trained the model: 0.7202800510904016
# Prediction accuracy of synthetic data: 0.500979232697857
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 22
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.010691139599791857
# Prediction accuracy of synthetic data: 0.5008562372865321
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 22
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.010850628155136415
# Prediction accuracy of synthetic data: 0.4990018449311699
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 22
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.010862116737512926
# Prediction accuracy of synthetic data: 0.5018023558351862
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 22
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.010849276557209759
# Prediction accuracy of synthetic data: 0.4995695160603624
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 22
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.01079453684118049
# TO-TB accuracy difference with same training data: 0.21983821372818013 with standard deviation: 0.0010145002922101792
# Prediction accuracy of synthetic data: 0.5002317990444203
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 22
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.010864819933366224
# Prediction accuracy of synthetic data: 0.5044609489569043
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 22
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.010673568826745422
# Prediction accuracy of synthetic data: 0.5023511045934056
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 22
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.010674244625708738
# Prediction accuracy of synthetic data: 0.5055773688443161
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 22
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.0106951943935718
# Prediction accuracy of synthetic data: 0.50201050191589
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 22
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.010703303981131696
# TO-TB accuracy difference with same training data: 0.21735370641941432 with standard deviation: 0.0018874948855295227
# Prediction accuracy of synthetic data: 0.5042811864326601
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 22
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.010905367871165682
# Prediction accuracy of synthetic data: 0.5017455887222669
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 22
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.010863468335439571
# Prediction accuracy of synthetic data: 0.5011211504801552
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 22
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.010814135011116893
# Prediction accuracy of synthetic data: 0.5012630682624533
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 22
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.010623559703459412
# diagnosis_age_0-20 present in original data, thus added to synthetic data with value 0
# Prediction accuracy of synthetic data: 0.4955674345995553
# diagnosis_age_0-20 present in original data, thus added to synthetic data with value 0
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 14
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.02565535604468383
# TO-TB accuracy difference with same training data: 0.21948436539098348 with standard deviation: 0.0028534195086314775
# subloc_8 present in original data, thus added to synthetic data with value 0
# stage_3A present in original data, thus added to synthetic data with value 0
# Prediction accuracy of synthetic data: 0.5433274989356166
# subloc_8 present in original data, thus added to synthetic data with value 0
# stage_3A present in original data, thus added to synthetic data with value 0
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 10
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.03435626769748535
# stage_2C present in original data, thus added to synthetic data with value 0
# diagnosis_age_0-20 present in original data, thus added to synthetic data with value 0
# Prediction accuracy of synthetic data: 0.5402715360234638
# stage_2C present in original data, thus added to synthetic data with value 0
# diagnosis_age_0-20 present in original data, thus added to synthetic data with value 0
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 10
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.03434545491407217
# stage_2C present in original data, thus added to synthetic data with value 0
# diagnosis_age_0-20 present in original data, thus added to synthetic data with value 0
# diagnosis_age_91-120 present in original data, thus added to synthetic data with value 0
# Prediction accuracy of synthetic data: 0.5239320686882066
# stage_2C present in original data, thus added to synthetic data with value 0
# diagnosis_age_0-20 present in original data, thus added to synthetic data with value 0
# diagnosis_age_91-120 present in original data, thus added to synthetic data with value 0
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 9
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.04121022078352132
# diagnosis_age_0-20 present in original data, thus added to synthetic data with value 0
# Prediction accuracy of synthetic data: 0.49155589195326177
# diagnosis_age_0-20 present in original data, thus added to synthetic data with value 0
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 14
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.025187027363100026
# stage_3A present in original data, thus added to synthetic data with value 0
# stage_4C present in original data, thus added to synthetic data with value 0
# Prediction accuracy of synthetic data: 0.5487392970339183
# stage_3A present in original data, thus added to synthetic data with value 0
# stage_4C present in original data, thus added to synthetic data with value 0
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 10
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.03439343664046819
# TO-TB accuracy difference with same training data: 0.1907147925635082 with standard deviation: 0.020727335413204116
# subloc_0 present in original data, thus added to synthetic data with value 0
# subloc_2 present in original data, thus added to synthetic data with value 0
# subloc_9 present in original data, thus added to synthetic data with value 0
# stage_3A present in original data, thus added to synthetic data with value 0
# stage_4C present in original data, thus added to synthetic data with value 0
# stage_M present in original data, thus added to synthetic data with value 0
# stage_X present in original data, thus added to synthetic data with value 0
# diagnosis_age_0-20 present in original data, thus added to synthetic data with value 0
# diagnosis_age_91-120 present in original data, thus added to synthetic data with value 0
# Prediction accuracy of synthetic data: 1.0
# subloc_0 present in original data, thus added to synthetic data with value 0
# subloc_2 present in original data, thus added to synthetic data with value 0
# subloc_9 present in original data, thus added to synthetic data with value 0
# stage_3A present in original data, thus added to synthetic data with value 0
# stage_4C present in original data, thus added to synthetic data with value 0
# stage_M present in original data, thus added to synthetic data with value 0
# stage_X present in original data, thus added to synthetic data with value 0
# diagnosis_age_0-20 present in original data, thus added to synthetic data with value 0
# diagnosis_age_91-120 present in original data, thus added to synthetic data with value 0
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 4
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.06632155866272901
# subloc_2 present in original data, thus added to synthetic data with value 0
# subloc_4 present in original data, thus added to synthetic data with value 0
# subloc_6 present in original data, thus added to synthetic data with value 0
# stage_2 present in original data, thus added to synthetic data with value 0
# stage_2B present in original data, thus added to synthetic data with value 0
# stage_2C present in original data, thus added to synthetic data with value 0
# stage_3A present in original data, thus added to synthetic data with value 0
# stage_4 present in original data, thus added to synthetic data with value 0
# stage_4B present in original data, thus added to synthetic data with value 0
# stage_M present in original data, thus added to synthetic data with value 0
# diagnosis_age_0-20 present in original data, thus added to synthetic data with value 0
# diagnosis_age_21-50 present in original data, thus added to synthetic data with value 0
# diagnosis_age_91-120 present in original data, thus added to synthetic data with value 0
# Prediction accuracy of synthetic data: 0.5468186763801505
# subloc_2 present in original data, thus added to synthetic data with value 0
# subloc_4 present in original data, thus added to synthetic data with value 0
# subloc_6 present in original data, thus added to synthetic data with value 0
# stage_2 present in original data, thus added to synthetic data with value 0
# stage_2B present in original data, thus added to synthetic data with value 0
# stage_2C present in original data, thus added to synthetic data with value 0
# stage_3A present in original data, thus added to synthetic data with value 0
# stage_4 present in original data, thus added to synthetic data with value 0
# stage_4B present in original data, thus added to synthetic data with value 0
# stage_M present in original data, thus added to synthetic data with value 0
# diagnosis_age_0-20 present in original data, thus added to synthetic data with value 0
# diagnosis_age_21-50 present in original data, thus added to synthetic data with value 0
# diagnosis_age_91-120 present in original data, thus added to synthetic data with value 0
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 2
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.054747149817872175
# subloc_4 present in original data, thus added to synthetic data with value 0
# subloc_6 present in original data, thus added to synthetic data with value 0
# subloc_8 present in original data, thus added to synthetic data with value 0
# subloc_9 present in original data, thus added to synthetic data with value 0
# stage_2C present in original data, thus added to synthetic data with value 0
# stage_3A present in original data, thus added to synthetic data with value 0
# stage_3B present in original data, thus added to synthetic data with value 0
# stage_4 present in original data, thus added to synthetic data with value 0
# stage_4A present in original data, thus added to synthetic data with value 0
# stage_M present in original data, thus added to synthetic data with value 0
# stage_X present in original data, thus added to synthetic data with value 0
# diagnosis_age_0-20 present in original data, thus added to synthetic data with value 0
# lymph_pos_1-89 present in original data, thus added to synthetic data with value 0
# Prediction accuracy of synthetic data: 0.422820379393538
# subloc_4 present in original data, thus added to synthetic data with value 0
# subloc_6 present in original data, thus added to synthetic data with value 0
# subloc_8 present in original data, thus added to synthetic data with value 0
# subloc_9 present in original data, thus added to synthetic data with value 0
# stage_2C present in original data, thus added to synthetic data with value 0
# stage_3A present in original data, thus added to synthetic data with value 0
# stage_3B present in original data, thus added to synthetic data with value 0
# stage_4 present in original data, thus added to synthetic data with value 0
# stage_4A present in original data, thus added to synthetic data with value 0
# stage_M present in original data, thus added to synthetic data with value 0
# stage_X present in original data, thus added to synthetic data with value 0
# diagnosis_age_0-20 present in original data, thus added to synthetic data with value 0
# lymph_pos_1-89 present in original data, thus added to synthetic data with value 0
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 2
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.05469173430287957
# stage_3 present in original data, thus added to synthetic data with value 0
# stage_3A present in original data, thus added to synthetic data with value 0
# stage_3B present in original data, thus added to synthetic data with value 0
# stage_4 present in original data, thus added to synthetic data with value 0
# stage_4B present in original data, thus added to synthetic data with value 0
# stage_M present in original data, thus added to synthetic data with value 0
# diagnosis_age_21-50 present in original data, thus added to synthetic data with value 0
# Prediction accuracy of synthetic data: 0.4687733573016699
# stage_3 present in original data, thus added to synthetic data with value 0
# stage_3A present in original data, thus added to synthetic data with value 0
# stage_3B present in original data, thus added to synthetic data with value 0
# stage_4 present in original data, thus added to synthetic data with value 0
# stage_4B present in original data, thus added to synthetic data with value 0
# stage_M present in original data, thus added to synthetic data with value 0
# diagnosis_age_21-50 present in original data, thus added to synthetic data with value 0
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 4
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.057052975880735005
# subloc_9 present in original data, thus added to synthetic data with value 0
# stage_2C present in original data, thus added to synthetic data with value 0
# stage_3 present in original data, thus added to synthetic data with value 0
# stage_3A present in original data, thus added to synthetic data with value 0
# stage_4 present in original data, thus added to synthetic data with value 0
# stage_M present in original data, thus added to synthetic data with value 0
# stage_X present in original data, thus added to synthetic data with value 0
# diagnosis_age_0-20 present in original data, thus added to synthetic data with value 0
# diagnosis_age_51-70 present in original data, thus added to synthetic data with value 0
# Prediction accuracy of synthetic data: 0.6928236908084583
# subloc_9 present in original data, thus added to synthetic data with value 0
# stage_2C present in original data, thus added to synthetic data with value 0
# stage_3 present in original data, thus added to synthetic data with value 0
# stage_3A present in original data, thus added to synthetic data with value 0
# stage_4 present in original data, thus added to synthetic data with value 0
# stage_M present in original data, thus added to synthetic data with value 0
# stage_X present in original data, thus added to synthetic data with value 0
# diagnosis_age_0-20 present in original data, thus added to synthetic data with value 0
# diagnosis_age_51-70 present in original data, thus added to synthetic data with value 0
# total number of samples is: 105695
# total number of ori rules is: 28
# total number of rules that syn follows from ori are: 4
# Both datasets use the same leaf nodes: False
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# leaf node not reached by synthetic dataset
# Support distance: 0.06586066376974177
# TO-TB accuracy difference with same training data: 0.0940328303136383 with standard deviation: 0.20814079728725343
# TB-TO accuracy difference and support difference for DecisionTreeClassifier : [0.21983821372818013, 0.21735370641941432, 0.21948436539098348, 0.1907147925635082, 0.0940328303136383] [0.01080953957816629, 0.010722226352104774, 0.01377237739317308, 0.03389848147972942, 0.059734816486791506]

# %%
labels = ['very low', 'low', 'medium', 'high', 'very high']

# %%
QMbar_one_DP_alg(QM=pb_TO_TB, QMerror = pb_TO_TB_ERRORS, QMname='TO-TB Accuracy Difference PB', labels=labels)
QMbar_one_DP_alg(QM=pb_SD, QMerror = pb_SD_ERRORS, QMname='Support Distance PB', labels=labels)

# %%
QMbar_one_DP_alg(QM=ms_TO_TB, QMerror = ms_TO_TB_ERRORS, QMname='TO-TB Accuracy Difference MS', labels=labels)
QMbar_one_DP_alg(QM=ms_SD, QMerror = ms_SD_ERRORS, QMname='Support Distance MS', labels=labels)

# %% [markdown]
# # Combined visualization

# %%
QM_TO_TB_ori = ms_TO_TB_ORI+pb_TO_TB_ORI
QM_TO_TB = ms_TO_TB+pb_TO_TB
QM_TO_TB_error = ms_TO_TB_ERRORS+pb_TO_TB_ERRORS

QM_SD = ms_SD+pb_SD
QM_SD_error = ms_SD_ERRORS+pb_SD_ERRORS

# %%
fig1 = QMbar_two_DP_algs(QM=QM_TO_TB, QMerror = QM_TO_TB_error, QMname='TO_TB Accuracy Difference', QMori = QM_TO_TB_ori, labels=labels)
fig1.savefig('C:\\Users\\bde2002.53381\\Desktop\\master-thesis\\experiments\\evaluation_results\\Final Result TO_TB Accuracy Difference-subset_3.png', bbox_inches='tight', dpi=100)

fig2 = SupportDistancebar(QM=QM_SD, QMerror = QM_SD_error, QMname='Support Distance', QMori = QM_TO_TB_ori, labels=labels)
fig2.savefig('C:\\Users\\bde2002.53381\\Desktop\\master-thesis\\experiments\\evaluation_results\\Final Result Support Distance-subset_3.png', bbox_inches='tight', dpi=100)
# Out:
# 2
